# %%
import time 
import requests
import re

# Input = <Youtube Channel ID>, <Youtube Data API Key>
# Output = Count of subscriber of Youtube Channel
def get_gudok(channel_ID, key):
    
    # get Json info 
    URL = 'https://www.googleapis.com/youtube/v3/channels?&part=statistics&id={}&key={}' .format(channel_ID ,key)
    result = requests.get(URL)
    result = result.json()
    
    #print(result['items'])
    #print(result['items'][0]['statistics']['viewCount'])
    #print(result['items'][0]['statistics']['subscriberCount'])
    
    # extract 'subscriberCount' from Json info 
    gudok = result['items'][0]['statistics']['subscriberCount']
    
    return gudok

# Input = <Youtube Video ID>, <Youtube Data API Key>
# Output = Count of view of Youtube Video
def get_johyeah(video_ID, key):
    
    # get Json info 
    URL = 'https://www.googleapis.com/youtube/v3/videos?part=snippet&part=statistics&id={}&key={}' .format(video_ID ,key)
    result = requests.get(URL)
    result = result.json()
    
    #print(result['items'])
    #print("조회수 : ",result['items'][0]['statistics']['viewCount'])
    result['items'][0]['statistics']['likeCount']
    result['items'][0]['statistics']['dislikeCount']
    result['items'][0]['statistics']['commentCount']
    
    # extract 'viewCount' from Json info 
    johyeah = result['items'][0]['statistics']['viewCount']
    
    result['items'][0]['snippet']['thumbnails']['medium']['url']
    #urlretrieve(image1[idx], './thumbnail/'+str(idx)+'.jpg')
    
    return johyeah
    

# Youtube Data API Key : KSB
key = 'AIzaSyBOXZu2peu80H1wBHmeG67RXMMIbIdaxPM'

# Search Keyword
search_word = "IU"
#search_word = input("검색어를 입력하세요 : ")

# part=snippet
URL = "https://www.googleapis.com/youtube/v3/search?part=snippet&key=AIzaSyBOXZu2peu80H1wBHmeG67RXMMIbIdaxPM&q="+search_word
# part=id
#URL = "https://www.googleapis.com/youtube/v3/search?part=id&key=AIzaSyBOXZu2peu80H1wBHmeG67RXMMIbIdaxPM&q="+search_word

result = requests.get(URL)
result = result.json()

try :
    idx = 0
    while True : #(result["items"][idx] != None): 
        
        if "youtube#video" == (result["items"][idx]["id"]["kind"]):
            
            # Video ID
            video_ID = result["items"][idx]["id"]["videoId"]
            view_Count = get_johyeah(video_ID, key)
            # Channel ID
            channel_ID = result["items"][idx]["snippet"]["channelId"]
            # subscriber_Count 
            subscriber_Count = get_gudok(channel_ID, key)
            
            upload_Time = result["items"][idx]["snippet"]["publishedAt"]
            video_Title = result["items"][idx]["snippet"]["title"]
            
            print(idx, video_Title, view_Count, subscriber_Count)
            
        else:
            print(idx, " = channel")
        idx += 1
except :
    pass
# Out:
# 0 [MV] IU(아이유) _ eight(에잇) (Prod.&amp;Feat. SUGA of BTS) 66547827 20100000
# 1 [MV] IU(아이유) _ Into the I-LAND 4421494 20100000
# 2  = channel
# 3 [MV] IU(아이유) _ Blueming(블루밍) 55841942 20100000
# 4 [아이유의 집콕시그널] 아이유 엉망라이브 1409964 240000

# %%
import time 
import requests
import re

# 해당 링크의 파일을 저장해주는 모듈
from urllib.request import urlretrieve
# 폴더 생성
import os

# Input = <Youtube Channel ID>, <Youtube Data API Key>
# Output = Count of subscriber of Youtube Channel
def get_gudok(channel_ID, key):
    
    # get Json info 
    URL = 'https://www.googleapis.com/youtube/v3/channels?&part=statistics&id={}&key={}' .format(channel_ID ,key)
    result = requests.get(URL)
    result = result.json()
    
    #print(result['items'])
    #print(result['items'][0]['statistics']['viewCount'])
    #print(result['items'][0]['statistics']['subscriberCount'])
    
    # extract 'subscriberCount' from Json info 
    gudok = result['items'][0]['statistics']['subscriberCount']
    
    return gudok

# Input = <Youtube Video ID>, <Youtube Data API Key>
# Output = Count of view of Youtube Video
def get_johyeah(video_ID, key, idx):
    
    # get Json info 
    URL = 'https://www.googleapis.com/youtube/v3/videos?part=snippet&part=statistics&id={}&key={}' .format(video_ID ,key)
    result = requests.get(URL)
    result = result.json()
    
    #print(result['items'])
    #print("조회수 : ",result['items'][0]['statistics']['viewCount'])
    result['items'][0]['statistics']['likeCount']
    result['items'][0]['statistics']['dislikeCount']
    result['items'][0]['statistics']['commentCount']
    
    # extract 'viewCount' from Json info 
    johyeah = result['items'][0]['statistics']['viewCount']
    
    image_URL = result['items'][0]['snippet']['thumbnails']['medium']['url']
    
    # Image Save
    urlretrieve(image_URL, './thumbnail/'+str(idx)+'.jpg')
    
    return johyeah
    

# 폴더 생성
try:
    if not (os.path.isdir("thumbnail")):
        os.makedirs(os.path.join("thumbnail"))
except OSError as e:
    if e.errno != errno.EEXIST:
        print("폴더 생성 실패")
        exit()
        
    
# Youtube Data API Key : KSB
key = 'AIzaSyBOXZu2peu80H1wBHmeG67RXMMIbIdaxPM'

# Search Keyword
search_word = "IU"
#search_word = input("검색어를 입력하세요 : ")

# part=snippet
URL = "https://www.googleapis.com/youtube/v3/search?part=snippet&key=AIzaSyBOXZu2peu80H1wBHmeG67RXMMIbIdaxPM&q="+search_word
# part=id
#URL = "https://www.googleapis.com/youtube/v3/search?part=id&key=AIzaSyBOXZu2peu80H1wBHmeG67RXMMIbIdaxPM&q="+search_word

result = requests.get(URL)
result = result.json()

try :
    idx = 0
    while True : #(result["items"][idx] != None): 
        
        if "youtube#video" == (result["items"][idx]["id"]["kind"]):
            
            # Video ID
            video_ID = result["items"][idx]["id"]["videoId"]
            view_Count = get_johyeah(video_ID, key, idx)
            # Channel ID
            channel_ID = result["items"][idx]["snippet"]["channelId"]
            # subscriber_Count 
            subscriber_Count = get_gudok(channel_ID, key)
            
            upload_Time = result["items"][idx]["snippet"]["publishedAt"]
            video_Title = result["items"][idx]["snippet"]["title"]
            
            print(idx, video_Title, view_Count, subscriber_Count)
            
        else:
            print(idx, " = channel")
        idx += 1
except :
    pass
# Out:
# 0 [MV] IU(아이유) _ eight(에잇) (Prod.&amp;Feat. SUGA of BTS) 66547827 20100000
# 1 [MV] IU(아이유) _ Into the I-LAND 4422288 20100000
# 2  = channel
# 3 [MV] IU(아이유) _ Blueming(블루밍) 55841942 20100000
# 4 [아이유의 집콕시그널] 아이유 엉망라이브 1409964 240000

# %%
print(result.text)
# Out:
# {
#   "kind": "youtube#searchListResponse",
#   "etag": "hkaX5qJLasQJCbX-Ta_T-738PKs",
#   "nextPageToken": "CAUQAA",
#   "regionCode": "KR",
#   "pageInfo": {
#     "totalResults": 1000000,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#searchResult",
#       "etag": "zq5uze10mCudwwWsKXhQcXjLW9Q",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "TgOu00Mf3kI"
#       },
#       "snippet": {
#         "publishedAt": "2020-05-06T09:00:16Z",
#         "channelId": "UCweOkPb1wVVH0Q0Tlj4a5Pw",
#         "title": "[MV] IU(아이유) _ eight(에잇) (Prod.&amp;Feat. SUGA of BTS)",
#         "description": "[MV] IU(아이유) _ eight(에잇) (Prod.&Feat. SUGA of BTS) K-POP Wonderland, 1theK K-POP의 모든 즐거움을 1theK(원더케이)에서 만나보세요! :) Welcome to the ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/TgOu00Mf3kI/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/TgOu00Mf3kI/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/TgOu00Mf3kI/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "1theK (원더케이)",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-05-06T09:00:16Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "4Xq2V2_SFjg8EVBqjFAEimc7amM",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "QYNwbZHmh8g"
#       },
#       "snippet": {
#         "publishedAt": "2020-06-19T09:00:10Z",
#         "channelId": "UCweOkPb1wVVH0Q0Tlj4a5Pw",
#         "title": "[MV] IU(아이유) _ Into the I-LAND",
#         "description": "[MV] IU(아이유) _ Into the I-LAND K-POP Wonderland, 1theK K-POP의 모든 즐거움을 1theK(원더케이)에서 만나보세요! :) Welcome to the official YouTube ...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/QYNwbZHmh8g/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/QYNwbZHmh8g/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/QYNwbZHmh8g/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "1theK (원더케이)",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-06-19T09:00:10Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "l05RtCfisj_CtcouSkcWBqvmVWk",
#       "id": {
#         "kind": "youtube#channel",
#         "channelId": "UC3SyT4_WLHzN7JmHQwKQZww"
#       },
#       "snippet": {
#         "publishedAt": "2017-02-13T06:00:29Z",
#         "channelId": "UC3SyT4_WLHzN7JmHQwKQZww",
#         "title": "이지금 [IU Official]",
#         "description": "아이유(IU) Official YouTube Channel.",
#         "thumbnails": {
#           "default": {
#             "url": "https://yt3.ggpht.com/-7jB5DCruPMM/AAAAAAAAAAI/AAAAAAAAAAA/OXomesN1YaM/s88-c-k-no-mo-rj-c0xffffff/photo.jpg"
#           },
#           "medium": {
#             "url": "https://yt3.ggpht.com/-7jB5DCruPMM/AAAAAAAAAAI/AAAAAAAAAAA/OXomesN1YaM/s240-c-k-no-mo-rj-c0xffffff/photo.jpg"
#           },
#           "high": {
#             "url": "https://yt3.ggpht.com/-7jB5DCruPMM/AAAAAAAAAAI/AAAAAAAAAAA/OXomesN1YaM/s800-c-k-no-mo-rj-c0xffffff/photo.jpg"
#           }
#         },
#         "channelTitle": "이지금 [IU Official]",
#         "liveBroadcastContent": "upcoming",
#         "publishTime": "2017-02-13T06:00:29Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "JKSIg1f-OatAAp0bYF6etu6wz28",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "D1PvIWdJ8xo"
#       },
#       "snippet": {
#         "publishedAt": "2019-11-18T09:00:02Z",
#         "channelId": "UCweOkPb1wVVH0Q0Tlj4a5Pw",
#         "title": "[MV] IU(아이유) _ Blueming(블루밍)",
#         "description": "[MV] IU(아이유) _ Blueming 1theK가 제작한 '1theK Originals-원더케이 오리지널' 채널이 오픈되었습니다:) 많은 관심과 구독 부탁드려요   NEW YouTube...",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/D1PvIWdJ8xo/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/D1PvIWdJ8xo/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/D1PvIWdJ8xo/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "1theK (원더케이)",
#         "liveBroadcastContent": "none",
#         "publishTime": "2019-11-18T09:00:02Z"
#       }
#     },
#     {
#       "kind": "youtube#searchResult",
#       "etag": "Lh1jiHvf5-yaRFXm7FR8uPI773k",
#       "id": {
#         "kind": "youtube#video",
#         "videoId": "DsCA9hwFIKY"
#       },
#       "snippet": {
#         "publishedAt": "2020-06-26T09:00:04Z",
#         "channelId": "UCU8MOmf9frN_60TIGvwlQEQ",
#         "title": "[아이유의 집콕시그널] 아이유 엉망라이브",
#         "description": "아이유 #IU #집콕시그널 [IU's Homebody signal] IU's Sloppy Live [아이유의 집콕시그널] 아이유 엉망라이브.",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/DsCA9hwFIKY/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/DsCA9hwFIKY/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/DsCA9hwFIKY/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           }
#         },
#         "channelTitle": "EDAM Entertainment",
#         "liveBroadcastContent": "none",
#         "publishTime": "2020-06-26T09:00:04Z"
#       }
#     }
#   ]
# }
